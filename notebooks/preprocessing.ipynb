# %%
import math
import pandas as pd
import numpy as np

df = pd.read_csv('../data/raw_total_fight_data.csv', sep=';')
fighter_details = pd.read_csv('../data/raw_fighter_details.csv', index_col='fighter_name')

# %%
df.head()
# Out:
#         R_fighter        B_fighter  R_KD  B_KD R_SIG_STR.  B_SIG_STR.  \
# 0  John Castaneda    Daniel Santos     1     1  57 of 106   69 of 134
# 1    Sodiq Yusuff      Don Shainis     0     0     9 of 9      3 of 3
# 2  Raoni Barcelos     Trevin Jones     1     0  73 of 119    11 of 57
# 3     Ilir Latifi  Aleksei Oleinik     0     0   38 of 48    28 of 70
# 4  Mackenzie Dern      Yan Xiaonan     0     0  61 of 151  113 of 195
#
#   R_SIG_STR_pct B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.  ... B_GROUND  \
# 0           53%           51%    67 of 118    71 of 137  ...   2 of 2
# 1          100%          100%       9 of 9       9 of 9  ...   0 of 0
# 2           61%           19%   119 of 171     15 of 61  ...   0 of 0
# 3           79%           40%     74 of 88    68 of 113  ...   0 of 0
# 4           40%           57%   224 of 339   151 of 240  ...   7 of 8
#
#                  win_by last_round last_round_time             Format  \
# 0                KO/TKO          2            4:28      3 Rnd (5-5-5)
# 1            Submission          1            0:30      3 Rnd (5-5-5)
# 2  Decision - Unanimous          3            5:00      3 Rnd (5-5-5)
# 3  Decision - Unanimous          3            5:00      3 Rnd (5-5-5)
# 4   Decision - Majority          5            5:00  5 Rnd (5-5-5-5-5)
#
#           Referee              date                location  \
# 0  Keith Peterson  October 01, 2022  Las Vegas, Nevada, USA
# 1  Jacob Montalvo  October 01, 2022  Las Vegas, Nevada, USA
# 2  Keith Peterson  October 01, 2022  Las Vegas, Nevada, USA
# 3  Jacob Montalvo  October 01, 2022  Las Vegas, Nevada, USA
# 4   Chris Tognoni  October 01, 2022  Las Vegas, Nevada, USA
#
#                  Fight_type          Winner
# 0         Catch Weight Bout   Daniel Santos
# 1        Featherweight Bout    Sodiq Yusuff
# 2         Bantamweight Bout  Raoni Barcelos
# 3          Heavyweight Bout     Ilir Latifi
# 4  Women's Strawweight Bout     Yan Xiaonan
#
# [5 rows x 41 columns]

# %%
fighter_details.drop(
    columns=["SLpM",
            "Str_Acc",
            "SApM",
            "Str_Def",
            "TD_Avg",
            "TD_Acc",
            "TD_Def",
            "Sub_Avg",
        ], inplace=True)

# %%
columns = ['R_SIG_STR.', 'B_SIG_STR.', 'R_TOTAL_STR.', 'B_TOTAL_STR.',
       'R_TD', 'B_TD', 'R_HEAD', 'B_HEAD', 'R_BODY','B_BODY', 'R_LEG', 'B_LEG', 
        'R_DISTANCE', 'B_DISTANCE', 'R_CLINCH','B_CLINCH', 'R_GROUND', 'B_GROUND']

# %%
attempt_suffix = '_att'
landed_suffix = '_landed'

for column in columns:
    df[column+attempt_suffix] = df[column].apply(lambda X: int(X.split('of')[1]))
    df[column+landed_suffix] = df[column].apply(lambda X: int(X.split('of')[0]))
    
df.drop(columns, axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'R_KD', 'B_KD', 'R_SIG_STR_pct',
#        'B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
#        'R_REV', 'B_REV', 'R_CTRL', 'B_CTRL', 'win_by', 'last_round',
#        'last_round_time', 'Format', 'Referee', 'date', 'location',
#        'Fight_type', 'Winner', 'R_SIG_STR._att', 'R_SIG_STR._landed',
#        'B_SIG_STR._att', 'B_SIG_STR._landed', 'R_TOTAL_STR._att',
#        'R_TOTAL_STR._landed', 'B_TOTAL_STR._att', 'B_TOTAL_STR._landed',
#        'R_TD_att', 'R_TD_landed', 'B_TD_att', 'B_TD_landed', 'R_HEAD_att',
#        'R_HEAD_landed', 'B_HEAD_att', 'B_HEAD_landed', 'R_BODY_att',
#        'R_BODY_landed', 'B_BODY_att', 'B_BODY_landed', 'R_LEG_att',
#        'R_LEG_landed', 'B_LEG_att', 'B_LEG_landed', 'R_DISTANCE_att',
#        'R_DISTANCE_landed', 'B_DISTANCE_att', 'B_DISTANCE_landed',
#        'R_CLINCH_att', 'R_CLINCH_landed', 'B_CLINCH_att', 'B_CLINCH_landed',
#        'R_GROUND_att', 'R_GROUND_landed', 'B_GROUND_att', 'B_GROUND_landed'],
#       dtype='object')

# %%
for column in df.columns:
    if df[column].isnull().sum() != 0:
        print(f"NaN values in {column} = {df[column].isnull().sum()}")
# Out:
# NaN values in Referee = 32
# NaN values in Winner = 121

# %%
df[df['Winner'].isnull()]['win_by'].value_counts()
# Out:
# Overturned              49
# Decision - Majority     28
# Could Not Continue      20
# Decision - Split        15
# Decision - Unanimous     6
# Other                    3
# Name: win_by, dtype: int64

# %%
df['Winner'].fillna('Draw', inplace=True)

# %%
pct_columns = ['R_SIG_STR_pct','B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct']

def pct_to_frac(X):
    if X != '---':
        return float(X.replace('%', ''))/100
    else:
        # if '---' means it's taking pct of `0 of 0`. 
        # Taking a call here to consider 0 landed of 0 attempted as 0 percentage
        return 0

for column in pct_columns:
    df[column] = df[column].apply(pct_to_frac)

# %%
df.T
# Out:
#                                        0                       1     \
# R_fighter                    John Castaneda            Sodiq Yusuff
# B_fighter                     Daniel Santos             Don Shainis
# R_KD                                      1                       0
# B_KD                                      1                       0
# R_SIG_STR_pct                          0.53                     1.0
# B_SIG_STR_pct                          0.51                     1.0
# R_TD_pct                                0.5                     0.0
# B_TD_pct                                0.5                     0.0
# R_SUB_ATT                                 0                       1
# B_SUB_ATT                                 0                       0
# R_REV                                     0                       0
# B_REV                                     0                       0
# R_CTRL                                 2:04                    0:02
# B_CTRL                                 0:52                    0:11
# win_by                               KO/TKO              Submission
# last_round                                2                       1
# last_round_time                        4:28                    0:30
# Format                        3 Rnd (5-5-5)           3 Rnd (5-5-5)
# Referee                      Keith Peterson          Jacob Montalvo
# date                       October 01, 2022        October 01, 2022
# location             Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# Fight_type                Catch Weight Bout      Featherweight Bout
# Winner                        Daniel Santos            Sodiq Yusuff
# R_SIG_STR._att                          106                       9
# R_SIG_STR._landed                        57                       9
# B_SIG_STR._att                          134                       3
# B_SIG_STR._landed                        69                       3
# R_TOTAL_STR._att                        118                       9
# R_TOTAL_STR._landed                      67                       9
# B_TOTAL_STR._att                        137                       9
# B_TOTAL_STR._landed                      71                       9
# R_TD_att                                  6                       0
# R_TD_landed                               3                       0
# B_TD_att                                  4                       1
# B_TD_landed                               2                       0
# R_HEAD_att                               89                       1
# R_HEAD_landed                            45                       1
# B_HEAD_att                              111                       0
# B_HEAD_landed                            52                       0
# R_BODY_att                               13                       8
# R_BODY_landed                             8                       8
# B_BODY_att                               19                       3
# B_BODY_landed                            14                       3
# R_LEG_att                                 4                       0
# R_LEG_landed                              4                       0
# B_LEG_att                                 4                       0
# B_LEG_landed                              3                       0
# R_DISTANCE_att                           87                       2
# R_DISTANCE_landed                        41                       2
# B_DISTANCE_att                          114                       1
# B_DISTANCE_landed                        53                       1
# R_CLINCH_att                             10                       7
# R_CLINCH_landed                           8                       7
# B_CLINCH_att                             18                       2
# B_CLINCH_landed                          14                       2
# R_GROUND_att                              9                       0
# R_GROUND_landed                           8                       0
# B_GROUND_att                              2                       0
# B_GROUND_landed                           2                       0
#
#                                        2                       3     \
# R_fighter                    Raoni Barcelos             Ilir Latifi
# B_fighter                      Trevin Jones         Aleksei Oleinik
# R_KD                                      1                       0
# B_KD                                      0                       0
# R_SIG_STR_pct                          0.61                    0.79
# B_SIG_STR_pct                          0.19                     0.4
# R_TD_pct                                0.4                     0.5
# B_TD_pct                                0.0                     0.0
# R_SUB_ATT                                 0                       0
# B_SUB_ATT                                 0                       0
# R_REV                                     0                       0
# B_REV                                     0                       0
# R_CTRL                                 7:07                    8:29
# B_CTRL                                 0:00                    0:02
# win_by                 Decision - Unanimous    Decision - Unanimous
# last_round                                3                       3
# last_round_time                        5:00                    5:00
# Format                        3 Rnd (5-5-5)           3 Rnd (5-5-5)
# Referee                      Keith Peterson          Jacob Montalvo
# date                       October 01, 2022        October 01, 2022
# location             Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# Fight_type                Bantamweight Bout        Heavyweight Bout
# Winner                       Raoni Barcelos             Ilir Latifi
# R_SIG_STR._att                          119                      48
# R_SIG_STR._landed                        73                      38
# B_SIG_STR._att                           57                      70
# B_SIG_STR._landed                        11                      28
# R_TOTAL_STR._att                        171                      88
# R_TOTAL_STR._landed                     119                      74
# B_TOTAL_STR._att                         61                     113
# B_TOTAL_STR._landed                      15                      68
# R_TD_att                                  5                       6
# R_TD_landed                               2                       3
# B_TD_att                                  2                       0
# B_TD_landed                               0                       0
# R_HEAD_att                               95                      40
# R_HEAD_landed                            51                      32
# B_HEAD_att                               47                      46
# B_HEAD_landed                             5                       9
# R_BODY_att                               21                       8
# R_BODY_landed                            19                       6
# B_BODY_att                                7                       9
# B_BODY_landed                             3                       7
# R_LEG_att                                 3                       0
# R_LEG_landed                              3                       0
# B_LEG_att                                 3                      15
# B_LEG_landed                              3                      12
# R_DISTANCE_att                           75                      27
# R_DISTANCE_landed                        39                      18
# B_DISTANCE_att                           56                      66
# B_DISTANCE_landed                        11                      27
# R_CLINCH_att                              3                       6
# R_CLINCH_landed                           2                       5
# B_CLINCH_att                              1                       4
# B_CLINCH_landed                           0                       1
# R_GROUND_att                             41                      15
# R_GROUND_landed                          32                      15
# B_GROUND_att                              0                       0
# B_GROUND_landed                           0                       0
#
#                                          4                       5     \
# R_fighter                      Mackenzie Dern             Randy Brown
# B_fighter                         Yan Xiaonan      Francisco Trinaldo
# R_KD                                        0                       1
# B_KD                                        0                       0
# R_SIG_STR_pct                             0.4                    0.42
# B_SIG_STR_pct                            0.57                    0.59
# R_TD_pct                                 0.18                     0.0
# B_TD_pct                                  0.0                    0.25
# R_SUB_ATT                                   2                       1
# B_SUB_ATT                                   0                       0
# R_REV                                       2                       1
# B_REV                                       0                       0
# R_CTRL                                   9:19                    0:38
# B_CTRL                                   4:11                    5:21
# win_by                    Decision - Majority    Decision - Unanimous
# last_round                                  5                       3
# last_round_time                          5:00                    5:00
# Format                      5 Rnd (5-5-5-5-5)           3 Rnd (5-5-5)
# Referee                         Chris Tognoni          Keith Peterson
# date                         October 01, 2022        October 01, 2022
# location               Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# Fight_type           Women's Strawweight Bout       Welterweight Bout
# Winner                            Yan Xiaonan             Randy Brown
# R_SIG_STR._att                            151                     141
# R_SIG_STR._landed                          61                      60
# B_SIG_STR._att                            195                      67
# B_SIG_STR._landed                         113                      40
# R_TOTAL_STR._att                          339                     148
# R_TOTAL_STR._landed                       224                      65
# B_TOTAL_STR._att                          240                     111
# B_TOTAL_STR._landed                       151                      82
# R_TD_att                                   11                       1
# R_TD_landed                                 2                       0
# B_TD_att                                    0                       4
# B_TD_landed                                 0                       1
# R_HEAD_att                                132                     101
# R_HEAD_landed                              45                      30
# B_HEAD_att                                126                      44
# B_HEAD_landed                              53                      20
# R_BODY_att                                 13                      16
# R_BODY_landed                              10                      10
# B_BODY_att                                 21                      12
# B_BODY_landed                              14                       9
# R_LEG_att                                   6                      24
# R_LEG_landed                                6                      20
# B_LEG_att                                  48                      11
# B_LEG_landed                               46                      11
# R_DISTANCE_att                            136                     136
# R_DISTANCE_landed                          52                      56
# B_DISTANCE_att                            178                      59
# B_DISTANCE_landed                         100                      33
# R_CLINCH_att                                7                       1
# R_CLINCH_landed                             3                       0
# B_CLINCH_att                                9                       1
# B_CLINCH_landed                             6                       0
# R_GROUND_att                                8                       4
# R_GROUND_landed                             6                       4
# B_GROUND_att                                8                       7
# B_GROUND_landed                             7                       7
#
#                                        6                       7     \
# R_fighter                     Joaquim Silva              Mike Davis
# B_fighter                      Jesse Ronson    Viacheslav Borshchev
# R_KD                                      1                       0
# B_KD                                      0                       0
# R_SIG_STR_pct                           0.5                    0.48
# B_SIG_STR_pct                          0.46                    0.53
# R_TD_pct                                0.0                    0.81
# B_TD_pct                                0.0                     0.0
# R_SUB_ATT                                 0                       1
# B_SUB_ATT                                 0                       0
# R_REV                                     0                       0
# B_REV                                     0                       1
# R_CTRL                                 0:11                    8:02
# B_CTRL                                 0:00                    0:14
# win_by                               KO/TKO    Decision - Unanimous
# last_round                                2                       3
# last_round_time                        3:08                    5:00
# Format                        3 Rnd (5-5-5)           3 Rnd (5-5-5)
# Referee                      Keith Peterson            Kerry Hatley
# date                       October 01, 2022        October 01, 2022
# location             Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# Fight_type                 Lightweight Bout        Lightweight Bout
# Winner                        Joaquim Silva              Mike Davis
# R_SIG_STR._att                           90                     133
# R_SIG_STR._landed                        45                      65
# B_SIG_STR._att                           83                     118
# B_SIG_STR._landed                        39                      63
# R_TOTAL_STR._att                         96                     174
# R_TOTAL_STR._landed                      51                     101
# B_TOTAL_STR._att                         83                     139
# B_TOTAL_STR._landed                      39                      84
# R_TD_att                                  0                      11
# R_TD_landed                               0                       9
# B_TD_att                                  1                       0
# B_TD_landed                               0                       0
# R_HEAD_att                               67                     118
# R_HEAD_landed                            26                      53
# B_HEAD_att                               55                      81
# B_HEAD_landed                            22                      29
# R_BODY_att                               16                       7
# R_BODY_landed                            12                       5
# B_BODY_att                               18                      13
# B_BODY_landed                            11                      10
# R_LEG_att                                 7                       8
# R_LEG_landed                              7                       7
# B_LEG_att                                10                      24
# B_LEG_landed                              6                      24
# R_DISTANCE_att                           76                      75
# R_DISTANCE_landed                        38                      27
# B_DISTANCE_att                           83                     115
# B_DISTANCE_landed                        39                      62
# R_CLINCH_att                              0                       1
# R_CLINCH_landed                           0                       1
# B_CLINCH_att                              0                       0
# B_CLINCH_landed                           0                       0
# R_GROUND_att                             14                      57
# R_GROUND_landed                           7                      37
# B_GROUND_att                              0                       3
# B_GROUND_landed                           0                       1
#
#                                        8                       9     ...  \
# R_fighter                   Krzysztof Jotko      Julija Stoliarenko  ...
# B_fighter                     Brendan Allen        Chelsea Chandler  ...
# R_KD                                      0                       0  ...
# B_KD                                      0                       0  ...
# R_SIG_STR_pct                           0.5                    0.44  ...
# B_SIG_STR_pct                           0.5                    0.54  ...
# R_TD_pct                                0.0                    0.33  ...
# B_TD_pct                                1.0                     0.0  ...
# R_SUB_ATT                                 0                       0  ...
# B_SUB_ATT                                 1                       0  ...
# R_REV                                     0                       0  ...
# B_REV                                     1                       0  ...
# R_CTRL                                 1:33                    0:19  ...
# B_CTRL                                 2:24                    2:05  ...
# win_by                           Submission                  KO/TKO  ...
# last_round                                1                       1  ...
# last_round_time                        4:17                    4:15  ...
# Format                        3 Rnd (5-5-5)           3 Rnd (5-5-5)  ...
# Referee                        Kerry Hatley          Jacob Montalvo  ...
# date                       October 01, 2022        October 01, 2022  ...
# location             Las Vegas, Nevada, USA  Las Vegas, Nevada, USA  ...
# Fight_type                Middleweight Bout       Catch Weight Bout  ...
# Winner                        Brendan Allen        Chelsea Chandler  ...
# R_SIG_STR._att                            6                      27  ...
# R_SIG_STR._landed                         3                      12  ...
# B_SIG_STR._att                            6                      70  ...
# B_SIG_STR._landed                         3                      38  ...
# R_TOTAL_STR._att                         26                      36  ...
# R_TOTAL_STR._landed                      21                      20  ...
# B_TOTAL_STR._att                         16                      81  ...
# B_TOTAL_STR._landed                      12                      47  ...
# R_TD_att                                  0                       3  ...
# R_TD_landed                               0                       1  ...
# B_TD_att                                  1                       0  ...
# B_TD_landed                               1                       0  ...
# R_HEAD_att                                5                      18  ...
# R_HEAD_landed                             3                       5  ...
# B_HEAD_att                                4                      64  ...
# B_HEAD_landed                             1                      34  ...
# R_BODY_att                                1                       4  ...
# R_BODY_landed                             0                       3  ...
# B_BODY_att                                1                       6  ...
# B_BODY_landed                             1                       4  ...
# R_LEG_att                                 0                       5  ...
# R_LEG_landed                              0                       4  ...
# B_LEG_att                                 1                       0  ...
# B_LEG_landed                              1                       0  ...
# R_DISTANCE_att                            3                      27  ...
# R_DISTANCE_landed                         0                      12  ...
# B_DISTANCE_att                            4                      43  ...
# B_DISTANCE_landed                         2                      17  ...
# R_CLINCH_att                              0                       0  ...
# R_CLINCH_landed                           0                       0  ...
# B_CLINCH_att                              0                       0  ...
# B_CLINCH_landed                           0                       0  ...
# R_GROUND_att                              3                       0  ...
# R_GROUND_landed                           3                       0  ...
# B_GROUND_att                              2                      27  ...
# B_GROUND_landed                           1                      21  ...
#
#                                       6797                   6798  \
# R_fighter                    Patrick Smith          Remco Pardoel
# B_fighter                     Scott Morris           Orlando Wiet
# R_KD                                     0                      0
# B_KD                                     0                      0
# R_SIG_STR_pct                         0.76                    1.0
# B_SIG_STR_pct                          0.0                    0.5
# R_TD_pct                               0.0                    1.0
# B_TD_pct                               0.0                    0.0
# R_SUB_ATT                                0                      0
# B_SUB_ATT                                0                      0
# R_REV                                    0                      0
# B_REV                                    0                      0
# R_CTRL                                  --                     --
# B_CTRL                                  --                     --
# win_by                              KO/TKO                 KO/TKO
# last_round                               1                      1
# last_round_time                       0:30                   1:29
# Format                       No Time Limit          No Time Limit
# Referee                      John McCarthy          John McCarthy
# date                        March 11, 1994         March 11, 1994
# location             Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type                Open Weight Bout       Open Weight Bout
# Winner                       Patrick Smith          Remco Pardoel
# R_SIG_STR._att                          17                      7
# R_SIG_STR._landed                       13                      7
# B_SIG_STR._att                           0                      2
# B_SIG_STR._landed                        0                      1
# R_TOTAL_STR._att                        25                      7
# R_TOTAL_STR._landed                     19                      7
# B_TOTAL_STR._att                         0                      7
# B_TOTAL_STR._landed                      0                      5
# R_TD_att                                 0                      1
# R_TD_landed                              0                      1
# B_TD_att                                 1                      0
# B_TD_landed                              0                      0
# R_HEAD_att                              16                      7
# R_HEAD_landed                           12                      7
# B_HEAD_att                               0                      1
# B_HEAD_landed                            0                      0
# R_BODY_att                               1                      0
# R_BODY_landed                            1                      0
# B_BODY_att                               0                      0
# B_BODY_landed                            0                      0
# R_LEG_att                                0                      0
# R_LEG_landed                             0                      0
# B_LEG_att                                0                      1
# B_LEG_landed                             0                      1
# R_DISTANCE_att                           0                      0
# R_DISTANCE_landed                        0                      0
# B_DISTANCE_att                           0                      2
# B_DISTANCE_landed                        0                      1
# R_CLINCH_att                             1                      0
# R_CLINCH_landed                          1                      0
# B_CLINCH_att                             0                      0
# B_CLINCH_landed                          0                      0
# R_GROUND_att                            16                      7
# R_GROUND_landed                         12                      7
# B_GROUND_att                             0                      0
# B_GROUND_landed                          0                      0
#
#                                       6799                   6800  \
# R_fighter                    Remco Pardoel          Johnny Rhodes
# B_fighter               Alberta Cerra Leon            Fred Ettish
# R_KD                                     0                      1
# B_KD                                     0                      0
# R_SIG_STR_pct                         0.66                   0.44
# B_SIG_STR_pct                         0.33                   0.57
# R_TD_pct                               1.0                    0.0
# B_TD_pct                               0.0                    0.0
# R_SUB_ATT                                1                      1
# B_SUB_ATT                                0                      0
# R_REV                                    0                      0
# B_REV                                    0                      0
# R_CTRL                                  --                     --
# B_CTRL                                  --                     --
# win_by                          Submission             Submission
# last_round                               1                      1
# last_round_time                       9:51                   3:07
# Format                       No Time Limit          No Time Limit
# Referee                      John McCarthy          John McCarthy
# date                        March 11, 1994         March 11, 1994
# location             Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type                Open Weight Bout       Open Weight Bout
# Winner                       Remco Pardoel          Johnny Rhodes
# R_SIG_STR._att                           6                     29
# R_SIG_STR._landed                        4                     13
# B_SIG_STR._att                           3                      7
# B_SIG_STR._landed                        1                      4
# R_TOTAL_STR._att                        22                     38
# R_TOTAL_STR._landed                     20                     21
# B_TOTAL_STR._att                        11                     11
# B_TOTAL_STR._landed                      9                      7
# R_TD_att                                 1                      0
# R_TD_landed                              1                      0
# B_TD_att                                 0                      0
# B_TD_landed                              0                      0
# R_HEAD_att                               5                     28
# R_HEAD_landed                            4                     12
# B_HEAD_att                               3                      1
# B_HEAD_landed                            1                      0
# R_BODY_att                               0                      0
# R_BODY_landed                            0                      0
# B_BODY_att                               0                      4
# B_BODY_landed                            0                      2
# R_LEG_att                                1                      1
# R_LEG_landed                             0                      1
# B_LEG_att                                0                      2
# B_LEG_landed                             0                      2
# R_DISTANCE_att                           1                      6
# R_DISTANCE_landed                        0                      3
# B_DISTANCE_att                           1                      7
# B_DISTANCE_landed                        1                      4
# R_CLINCH_att                             0                      2
# R_CLINCH_landed                          0                      1
# B_CLINCH_att                             0                      0
# B_CLINCH_landed                          0                      0
# R_GROUND_att                             5                     21
# R_GROUND_landed                          4                      9
# B_GROUND_att                             2                      0
# B_GROUND_landed                          0                      0
#
#                                       6801                   6802  \
# R_fighter                    Jason DeLucia           Orlando Wiet
# B_fighter                      Scott Baker       Robert Lucarelli
# R_KD                                     0                      0
# B_KD                                     0                      0
# R_SIG_STR_pct                          0.6                   0.66
# B_SIG_STR_pct                          0.0                   0.33
# R_TD_pct                               0.0                    0.0
# B_TD_pct                               1.0                    1.0
# R_SUB_ATT                                5                      0
# B_SUB_ATT                                0                      1
# R_REV                                    4                      0
# B_REV                                    2                      0
# R_CTRL                                  --                     --
# B_CTRL                                  --                     --
# win_by                          Submission                 KO/TKO
# last_round                               1                      1
# last_round_time                       6:41                   2:50
# Format                       No Time Limit          No Time Limit
# Referee                      John McCarthy          John McCarthy
# date                        March 11, 1994         March 11, 1994
# location             Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type                Open Weight Bout       Open Weight Bout
# Winner                       Jason DeLucia           Orlando Wiet
# R_SIG_STR._att                           5                     12
# R_SIG_STR._landed                        3                      8
# B_SIG_STR._att                           2                      6
# B_SIG_STR._landed                        0                      2
# R_TOTAL_STR._att                        25                     15
# R_TOTAL_STR._landed                     20                     11
# B_TOTAL_STR._att                        23                      6
# B_TOTAL_STR._landed                     14                      2
# R_TD_att                                 1                      0
# R_TD_landed                              0                      0
# B_TD_att                                 1                      1
# B_TD_landed                              1                      1
# R_HEAD_att                               2                     11
# R_HEAD_landed                            1                      7
# B_HEAD_att                               2                      2
# B_HEAD_landed                            0                      1
# R_BODY_att                               2                      1
# R_BODY_landed                            1                      1
# B_BODY_att                               0                      1
# B_BODY_landed                            0                      0
# R_LEG_att                                1                      0
# R_LEG_landed                             1                      0
# B_LEG_att                                0                      3
# B_LEG_landed                             0                      1
# R_DISTANCE_att                           4                      3
# R_DISTANCE_landed                        2                      1
# B_DISTANCE_att                           2                      6
# B_DISTANCE_landed                        0                      2
# R_CLINCH_att                             0                      0
# R_CLINCH_landed                          0                      0
# B_CLINCH_att                             0                      0
# B_CLINCH_landed                          0                      0
# R_GROUND_att                             1                      9
# R_GROUND_landed                          1                      7
# B_GROUND_att                             0                      0
# B_GROUND_landed                          0                      0
#
#                                       6803                   6804  \
# R_fighter                    Frank Hamaker           Scott Morris
# B_fighter                  Thaddeus Luster         Sean Daugherty
# R_KD                                     0                      0
# B_KD                                     0                      0
# R_SIG_STR_pct                         0.66                    1.0
# B_SIG_STR_pct                          0.0                    0.0
# R_TD_pct                               1.0                    1.0
# B_TD_pct                               0.0                    0.0
# R_SUB_ATT                                3                      1
# B_SUB_ATT                                0                      0
# R_REV                                    1                      0
# B_REV                                    0                      0
# R_CTRL                                  --                     --
# B_CTRL                                  --                     --
# win_by                          Submission             Submission
# last_round                               1                      1
# last_round_time                       4:52                   0:20
# Format                       No Time Limit          No Time Limit
# Referee                      John McCarthy          John McCarthy
# date                        March 11, 1994         March 11, 1994
# location             Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type                Open Weight Bout       Open Weight Bout
# Winner                       Frank Hamaker           Scott Morris
# R_SIG_STR._att                           3                      1
# R_SIG_STR._landed                        2                      1
# B_SIG_STR._att                           0                      4
# B_SIG_STR._landed                        0                      0
# R_TOTAL_STR._att                        15                      2
# R_TOTAL_STR._landed                     14                      2
# B_TOTAL_STR._att                         0                      5
# B_TOTAL_STR._landed                      0                      1
# R_TD_att                                 1                      1
# R_TD_landed                              1                      1
# B_TD_att                                 1                      0
# B_TD_landed                              0                      0
# R_HEAD_att                               3                      1
# R_HEAD_landed                            2                      1
# B_HEAD_att                               0                      2
# B_HEAD_landed                            0                      0
# R_BODY_att                               0                      0
# R_BODY_landed                            0                      0
# B_BODY_att                               0                      0
# B_BODY_landed                            0                      0
# R_LEG_att                                0                      0
# R_LEG_landed                             0                      0
# B_LEG_att                                0                      2
# B_LEG_landed                             0                      0
# R_DISTANCE_att                           1                      0
# R_DISTANCE_landed                        1                      0
# B_DISTANCE_att                           0                      3
# B_DISTANCE_landed                        0                      0
# R_CLINCH_att                             0                      1
# R_CLINCH_landed                          0                      1
# B_CLINCH_att                             0                      1
# B_CLINCH_landed                          0                      0
# R_GROUND_att                             2                      0
# R_GROUND_landed                          1                      0
# B_GROUND_att                             0                      0
# B_GROUND_landed                          0                      0
#
#                                       6805                   6806
# R_fighter                    Patrick Smith          Johnny Rhodes
# B_fighter                       Ray Wizard          David Levicki
# R_KD                                     0                      0
# B_KD                                     0                      0
# R_SIG_STR_pct                          1.0                   0.64
# B_SIG_STR_pct                          1.0                    0.8
# R_TD_pct                               0.0                    1.0
# B_TD_pct                               0.0                    0.0
# R_SUB_ATT                                1                      0
# B_SUB_ATT                                0                      0
# R_REV                                    0                      0
# B_REV                                    0                      0
# R_CTRL                                  --                     --
# B_CTRL                                  --                     --
# win_by                          Submission                 KO/TKO
# last_round                               1                      1
# last_round_time                       0:58                  12:13
# Format                       No Time Limit          No Time Limit
# Referee                      John McCarthy          John McCarthy
# date                        March 11, 1994         March 11, 1994
# location             Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type                Open Weight Bout       Open Weight Bout
# Winner                       Patrick Smith          Johnny Rhodes
# R_SIG_STR._att                           1                     17
# R_SIG_STR._landed                        1                     11
# B_SIG_STR._att                           1                      5
# B_SIG_STR._landed                        1                      4
# R_TOTAL_STR._att                         1                     86
# R_TOTAL_STR._landed                      1                     74
# B_TOTAL_STR._att                         2                    102
# B_TOTAL_STR._landed                      2                     95
# R_TD_att                                 1                      1
# R_TD_landed                              0                      1
# B_TD_att                                 0                      0
# B_TD_landed                              0                      0
# R_HEAD_att                               0                     15
# R_HEAD_landed                            0                      9
# B_HEAD_att                               0                      5
# B_HEAD_landed                            0                      4
# R_BODY_att                               1                      1
# R_BODY_landed                            1                      1
# B_BODY_att                               0                      0
# B_BODY_landed                            0                      0
# R_LEG_att                                0                      1
# R_LEG_landed                             0                      1
# B_LEG_att                                1                      0
# B_LEG_landed                             1                      0
# R_DISTANCE_att                           0                      1
# R_DISTANCE_landed                        0                      1
# B_DISTANCE_att                           1                      2
# B_DISTANCE_landed                        1                      1
# R_CLINCH_att                             1                      1
# R_CLINCH_landed                          1                      1
# B_CLINCH_att                             0                      2
# B_CLINCH_landed                          0                      2
# R_GROUND_att                             0                     15
# R_GROUND_landed                          0                      9
# B_GROUND_att                             0                      1
# B_GROUND_landed                          0                      1
#
# [59 rows x 6807 columns]

# %%
df['title_bout'] = df['Fight_type'].apply(lambda X: True if 'Title Bout' in X else False)

# %%
def make_weight_class(X):
    for weight_class in weight_classes:
        if weight_class in X:
            return weight_class
    if X == 'Catch Weight Bout' or 'Catchweight Bout':
        return 'Catch Weight'
    else:
        return 'Open Weight'

# %%
weight_classes = ['Women\'s Strawweight', 'Women\'s Bantamweight', 
                  'Women\'s Featherweight', 'Women\'s Flyweight', 'Lightweight', 
                  'Welterweight', 'Middleweight','Light Heavyweight', 
                  'Heavyweight', 'Featherweight','Bantamweight', 'Flyweight', 'Open Weight']

df['weight_class'] = df['Fight_type'].apply(make_weight_class)

# %%
df[df['weight_class'].isnull()]['Fight_type'].value_counts()
# Out:
# Series([], Name: Fight_type, dtype: int64)

# %%
df['Fight_type'].value_counts()
# Out:
# Lightweight Bout                                                       1150
# Welterweight Bout                                                      1121
# Middleweight Bout                                                       865
# Featherweight Bout                                                      616
# Heavyweight Bout                                                        589
#                                                                        ...
# Ultimate Fighter China Welterweight Tournament Title Bout                 1
# TUF Nations Canada vs. Australia Welterweight Tournament Title Bout       1
# Ultimate Fighter Brazil 3 Middleweight Tournament Title Bout              1
# Ultimate Fighter Brazil 3 Heavyweight Tournament Title Bout               1
# UFC 2 Tournament Title Bout                                               1
# Name: Fight_type, Length: 109, dtype: int64

# %%
df.drop(columns=['Fight_type'], inplace=True)

# %%
df['Format'].value_counts()
# Out:
# 3 Rnd (5-5-5)           5997
# 5 Rnd (5-5-5-5-5)        590
# 1 Rnd + OT (12-3)         80
# No Time Limit             29
# 3 Rnd + OT (5-5-5-5)      26
# 1 Rnd (20)                21
# 1 Rnd + 2OT (15-3-3)      20
# 2 Rnd (5-5)               14
# 1 Rnd (15)                 8
# 1 Rnd (10)                 6
# 1 Rnd (12)                 4
# 1 Rnd + OT (30-5)          3
# 1 Rnd + OT (15-3)          2
# 1 Rnd (18)                 2
# 1 Rnd + OT (27-3)          1
# 1 Rnd + OT (30-3)          1
# 1 Rnd (30)                 1
# 1 Rnd + OT (31-5)          1
# 1 Rnd + 2OT (24-3-3)       1
# Name: Format, dtype: int64

# %%
time_in_first_round = {'3 Rnd (5-5-5)': 5*60, '5 Rnd (5-5-5-5-5)': 5*60, '1 Rnd + OT (12-3)': 12*60,
       'No Time Limit': 1, '3 Rnd + OT (5-5-5-5)': 5*60, '1 Rnd (20)': 1*20,
       '2 Rnd (5-5)': 5*60, '1 Rnd (15)': 15*60, '1 Rnd (10)': 10*60,
       '1 Rnd (12)':12*60, '1 Rnd + OT (30-5)': 30*60, '1 Rnd (18)': 18*60, '1 Rnd + OT (15-3)': 15*60,
       '1 Rnd (30)': 30*60, '1 Rnd + OT (31-5)': 31*5,
       '1 Rnd + OT (27-3)': 27*60, '1 Rnd + OT (30-3)': 30*60}

exception_format_time = {'1 Rnd + 2OT (15-3-3)': [15*60, 3*60], '1 Rnd + 2OT (24-3-3)': [24*60, 3*60]}

# %%
# Converting to seconds
df['last_round_time'] = df['last_round_time'].apply(lambda X: int(X.split(':')[0])*60 + int(X.split(':')[1]))

# %%
def get_total_time(row):
    if row['Format'] in time_in_first_round.keys():
        return (row['last_round'] - 1) * time_in_first_round[row['Format']] + row['last_round_time']
    elif row['Format'] in exception_format_time.keys():
        if (row['last_round'] - 1) >= 2:
            return exception_format_time[row['Format']][0] + (row['last_round'] - 2) * \
                    exception_format_time[row['Format']][1] + row['last_round_time']
        else:
            return (row['last_round'] - 1) * exception_format_time[row['Format']][0] + row['last_round_time']
    
# So if the fight ended in round 1, we only need last_round_time. 
# If it ended in round 2, we need the full time of round 1 and the last_round_time
# This works for fights with same time in each round and fights with only two rounds.

# %%
df['total_time_fought(seconds)'] = df.apply(get_total_time, axis=1)

# %%
def get_no_of_rounds(X):
    if X == 'No Time Limit':
        return 1
    else:
        return len(X.split('(')[1].replace(')', '').split('-'))

df['no_of_rounds'] = df['Format'].apply(get_no_of_rounds)

# %%
df.drop(columns=['Format', 'last_round_time'], inplace=True)

# %%
CTRL_columns = ['R_CTRL','B_CTRL']

def conv_to_sec(X):
    if X != '--':
        return int(X.split(':')[0])*60 + int(X.split(':')[1])
    else:
        # if '--' means there was no time spent on the ground. 
        # Taking a call here to consider this as 0 seconds
        return 0

for column in CTRL_columns:
    df[column+'_time(seconds)'] = df[column].apply(conv_to_sec)

# %%
df.drop(columns=['R_CTRL', 'B_CTRL'], inplace=True)

# %%
df.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'R_KD', 'B_KD', 'R_SIG_STR_pct',
#        'B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
#        'R_REV', 'B_REV', 'win_by', 'last_round', 'Referee', 'date', 'location',
#        'Winner', 'R_SIG_STR._att', 'R_SIG_STR._landed', 'B_SIG_STR._att',
#        'B_SIG_STR._landed', 'R_TOTAL_STR._att', 'R_TOTAL_STR._landed',
#        'B_TOTAL_STR._att', 'B_TOTAL_STR._landed', 'R_TD_att', 'R_TD_landed',
#        'B_TD_att', 'B_TD_landed', 'R_HEAD_att', 'R_HEAD_landed', 'B_HEAD_att',
#        'B_HEAD_landed', 'R_BODY_att', 'R_BODY_landed', 'B_BODY_att',
#        'B_BODY_landed', 'R_LEG_att', 'R_LEG_landed', 'B_LEG_att',
#        'B_LEG_landed', 'R_DISTANCE_att', 'R_DISTANCE_landed', 'B_DISTANCE_att',
#        'B_DISTANCE_landed', 'R_CLINCH_att', 'R_CLINCH_landed', 'B_CLINCH_att',
#        'B_CLINCH_landed', 'R_GROUND_att', 'R_GROUND_landed', 'B_GROUND_att',
#        'B_GROUND_landed', 'title_bout', 'weight_class',
#        'total_time_fought(seconds)', 'no_of_rounds', 'R_CTRL_time(seconds)',
#        'B_CTRL_time(seconds)'],
#       dtype='object')

# %%
df2 = df.copy()

# %%
df2.drop(['R_KD', 'B_KD', 'R_SIG_STR_pct',
       'B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
       'R_CTRL_time(seconds)', 'B_CTRL_time(seconds)', 'R_REV', 'B_REV', 'win_by', 'last_round', 
        'R_SIG_STR._att', 'R_SIG_STR._landed',
       'B_SIG_STR._att', 'B_SIG_STR._landed', 'R_TOTAL_STR._att',
       'R_TOTAL_STR._landed', 'B_TOTAL_STR._att', 'B_TOTAL_STR._landed',
       'R_TD_att', 'R_TD_landed', 'B_TD_att', 'B_TD_landed', 'R_HEAD_att',
       'R_HEAD_landed', 'B_HEAD_att', 'B_HEAD_landed', 'R_BODY_att',
       'R_BODY_landed', 'B_BODY_att', 'B_BODY_landed', 'R_LEG_att',
       'R_LEG_landed', 'B_LEG_att', 'B_LEG_landed', 'R_DISTANCE_att',
       'R_DISTANCE_landed', 'B_DISTANCE_att', 'B_DISTANCE_landed',
       'R_CLINCH_att', 'R_CLINCH_landed', 'B_CLINCH_att', 'B_CLINCH_landed',
       'R_GROUND_att', 'R_GROUND_landed', 'B_GROUND_att', 'B_GROUND_landed',
        'total_time_fought(seconds)'], axis=1, inplace=True)

# %%
# Out:
#                                 0                       1     \
# R_fighter             John Castaneda            Sodiq Yusuff
# B_fighter              Daniel Santos             Don Shainis
# Referee               Keith Peterson          Jacob Montalvo
# date                October 01, 2022        October 01, 2022
# location      Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# Winner                 Daniel Santos            Sodiq Yusuff
# title_bout                     False                   False
# weight_class            Catch Weight           Featherweight
# no_of_rounds                       3                       3
#
#                                 2                       3     \
# R_fighter             Raoni Barcelos             Ilir Latifi
# B_fighter               Trevin Jones         Aleksei Oleinik
# Referee               Keith Peterson          Jacob Montalvo
# date                October 01, 2022        October 01, 2022
# location      Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# Winner                Raoni Barcelos             Ilir Latifi
# title_bout                     False                   False
# weight_class            Bantamweight             Heavyweight
# no_of_rounds                       3                       3
#
#                                 4                       5     \
# R_fighter             Mackenzie Dern             Randy Brown
# B_fighter                Yan Xiaonan      Francisco Trinaldo
# Referee                Chris Tognoni          Keith Peterson
# date                October 01, 2022        October 01, 2022
# location      Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# Winner                   Yan Xiaonan             Randy Brown
# title_bout                     False                   False
# weight_class     Women's Strawweight            Welterweight
# no_of_rounds                       5                       3
#
#                                 6                       7     \
# R_fighter              Joaquim Silva              Mike Davis
# B_fighter               Jesse Ronson    Viacheslav Borshchev
# Referee               Keith Peterson            Kerry Hatley
# date                October 01, 2022        October 01, 2022
# location      Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# Winner                 Joaquim Silva              Mike Davis
# title_bout                     False                   False
# weight_class             Lightweight             Lightweight
# no_of_rounds                       3                       3
#
#                                 8                       9     ...  \
# R_fighter            Krzysztof Jotko      Julija Stoliarenko  ...
# B_fighter              Brendan Allen        Chelsea Chandler  ...
# Referee                 Kerry Hatley          Jacob Montalvo  ...
# date                October 01, 2022        October 01, 2022  ...
# location      Las Vegas, Nevada, USA  Las Vegas, Nevada, USA  ...
# Winner                 Brendan Allen        Chelsea Chandler  ...
# title_bout                     False                   False  ...
# weight_class            Middleweight            Catch Weight  ...
# no_of_rounds                       3                       3  ...
#
#                                6797                   6798  \
# R_fighter             Patrick Smith          Remco Pardoel
# B_fighter              Scott Morris           Orlando Wiet
# Referee               John McCarthy          John McCarthy
# date                 March 11, 1994         March 11, 1994
# location      Denver, Colorado, USA  Denver, Colorado, USA
# Winner                Patrick Smith          Remco Pardoel
# title_bout                    False                  False
# weight_class            Open Weight            Open Weight
# no_of_rounds                      1                      1
#
#                                6799                   6800  \
# R_fighter             Remco Pardoel          Johnny Rhodes
# B_fighter        Alberta Cerra Leon            Fred Ettish
# Referee               John McCarthy          John McCarthy
# date                 March 11, 1994         March 11, 1994
# location      Denver, Colorado, USA  Denver, Colorado, USA
# Winner                Remco Pardoel          Johnny Rhodes
# title_bout                    False                  False
# weight_class            Open Weight            Open Weight
# no_of_rounds                      1                      1
#
#                                6801                   6802  \
# R_fighter             Jason DeLucia           Orlando Wiet
# B_fighter               Scott Baker       Robert Lucarelli
# Referee               John McCarthy          John McCarthy
# date                 March 11, 1994         March 11, 1994
# location      Denver, Colorado, USA  Denver, Colorado, USA
# Winner                Jason DeLucia           Orlando Wiet
# title_bout                    False                  False
# weight_class            Open Weight            Open Weight
# no_of_rounds                      1                      1
#
#                                6803                   6804  \
# R_fighter             Frank Hamaker           Scott Morris
# B_fighter           Thaddeus Luster         Sean Daugherty
# Referee               John McCarthy          John McCarthy
# date                 March 11, 1994         March 11, 1994
# location      Denver, Colorado, USA  Denver, Colorado, USA
# Winner                Frank Hamaker           Scott Morris
# title_bout                    False                  False
# weight_class            Open Weight            Open Weight
# no_of_rounds                      1                      1
#
#                                6805                   6806
# R_fighter             Patrick Smith          Johnny Rhodes
# B_fighter                Ray Wizard          David Levicki
# Referee               John McCarthy          John McCarthy
# date                 March 11, 1994         March 11, 1994
# location      Denver, Colorado, USA  Denver, Colorado, USA
# Winner                Patrick Smith          Johnny Rhodes
# title_bout                    False                  False
# weight_class            Open Weight            Open Weight
# no_of_rounds                      1                      1
#
# [9 rows x 6807 columns]

# %%
red_fighters = df['R_fighter'].value_counts().index
blue_fighters = df['B_fighter'].value_counts().index

fighters = list(set(red_fighters) | set(blue_fighters))

# %%
def get_renamed_winner(row):
    if row['R_fighter'] == row['Winner']:
        return 'Red'
    elif row['B_fighter'] == row['Winner']:
        return 'Blue'
    elif row['Winner'] == 'Draw':
        return 'Draw'

df2['Winner'] = df2[['R_fighter', 'B_fighter', 'Winner']].apply(get_renamed_winner, axis=1)

# %%
df2.to_csv('../data/fight_arrangements.csv', index=False)
# Out:
#                                 0                       1     \
# R_fighter             John Castaneda            Sodiq Yusuff
# B_fighter              Daniel Santos             Don Shainis
# Referee               Keith Peterson          Jacob Montalvo
# date                October 01, 2022        October 01, 2022
# location      Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# Winner                          Blue                     Red
# title_bout                     False                   False
# weight_class            Catch Weight           Featherweight
# no_of_rounds                       3                       3
#
#                                 2                       3     \
# R_fighter             Raoni Barcelos             Ilir Latifi
# B_fighter               Trevin Jones         Aleksei Oleinik
# Referee               Keith Peterson          Jacob Montalvo
# date                October 01, 2022        October 01, 2022
# location      Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# Winner                           Red                     Red
# title_bout                     False                   False
# weight_class            Bantamweight             Heavyweight
# no_of_rounds                       3                       3
#
#                                 4                       5     \
# R_fighter             Mackenzie Dern             Randy Brown
# B_fighter                Yan Xiaonan      Francisco Trinaldo
# Referee                Chris Tognoni          Keith Peterson
# date                October 01, 2022        October 01, 2022
# location      Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# Winner                          Blue                     Red
# title_bout                     False                   False
# weight_class     Women's Strawweight            Welterweight
# no_of_rounds                       5                       3
#
#                                 6                       7     \
# R_fighter              Joaquim Silva              Mike Davis
# B_fighter               Jesse Ronson    Viacheslav Borshchev
# Referee               Keith Peterson            Kerry Hatley
# date                October 01, 2022        October 01, 2022
# location      Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# Winner                           Red                     Red
# title_bout                     False                   False
# weight_class             Lightweight             Lightweight
# no_of_rounds                       3                       3
#
#                                 8                       9     ...  \
# R_fighter            Krzysztof Jotko      Julija Stoliarenko  ...
# B_fighter              Brendan Allen        Chelsea Chandler  ...
# Referee                 Kerry Hatley          Jacob Montalvo  ...
# date                October 01, 2022        October 01, 2022  ...
# location      Las Vegas, Nevada, USA  Las Vegas, Nevada, USA  ...
# Winner                          Blue                    Blue  ...
# title_bout                     False                   False  ...
# weight_class            Middleweight            Catch Weight  ...
# no_of_rounds                       3                       3  ...
#
#                                6797                   6798  \
# R_fighter             Patrick Smith          Remco Pardoel
# B_fighter              Scott Morris           Orlando Wiet
# Referee               John McCarthy          John McCarthy
# date                 March 11, 1994         March 11, 1994
# location      Denver, Colorado, USA  Denver, Colorado, USA
# Winner                          Red                    Red
# title_bout                    False                  False
# weight_class            Open Weight            Open Weight
# no_of_rounds                      1                      1
#
#                                6799                   6800  \
# R_fighter             Remco Pardoel          Johnny Rhodes
# B_fighter        Alberta Cerra Leon            Fred Ettish
# Referee               John McCarthy          John McCarthy
# date                 March 11, 1994         March 11, 1994
# location      Denver, Colorado, USA  Denver, Colorado, USA
# Winner                          Red                    Red
# title_bout                    False                  False
# weight_class            Open Weight            Open Weight
# no_of_rounds                      1                      1
#
#                                6801                   6802  \
# R_fighter             Jason DeLucia           Orlando Wiet
# B_fighter               Scott Baker       Robert Lucarelli
# Referee               John McCarthy          John McCarthy
# date                 March 11, 1994         March 11, 1994
# location      Denver, Colorado, USA  Denver, Colorado, USA
# Winner                          Red                    Red
# title_bout                    False                  False
# weight_class            Open Weight            Open Weight
# no_of_rounds                      1                      1
#
#                                6803                   6804  \
# R_fighter             Frank Hamaker           Scott Morris
# B_fighter           Thaddeus Luster         Sean Daugherty
# Referee               John McCarthy          John McCarthy
# date                 March 11, 1994         March 11, 1994
# location      Denver, Colorado, USA  Denver, Colorado, USA
# Winner                          Red                    Red
# title_bout                    False                  False
# weight_class            Open Weight            Open Weight
# no_of_rounds                      1                      1
#
#                                6805                   6806
# R_fighter             Patrick Smith          Johnny Rhodes
# B_fighter                Ray Wizard          David Levicki
# Referee               John McCarthy          John McCarthy
# date                 March 11, 1994         March 11, 1994
# location      Denver, Colorado, USA  Denver, Colorado, USA
# Winner                          Red                    Red
# title_bout                    False                  False
# weight_class            Open Weight            Open Weight
# no_of_rounds                      1                      1
#
# [9 rows x 6807 columns]

# %%
df = pd.concat([df,pd.get_dummies(df['win_by'], prefix='win_by')],axis=1)
df.drop(['win_by'],axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'R_KD', 'B_KD', 'R_SIG_STR_pct',
#        'B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
#        'R_REV', 'B_REV', 'last_round', 'Referee', 'date', 'location', 'Winner',
#        'R_SIG_STR._att', 'R_SIG_STR._landed', 'B_SIG_STR._att',
#        'B_SIG_STR._landed', 'R_TOTAL_STR._att', 'R_TOTAL_STR._landed',
#        'B_TOTAL_STR._att', 'B_TOTAL_STR._landed', 'R_TD_att', 'R_TD_landed',
#        'B_TD_att', 'B_TD_landed', 'R_HEAD_att', 'R_HEAD_landed', 'B_HEAD_att',
#        'B_HEAD_landed', 'R_BODY_att', 'R_BODY_landed', 'B_BODY_att',
#        'B_BODY_landed', 'R_LEG_att', 'R_LEG_landed', 'B_LEG_att',
#        'B_LEG_landed', 'R_DISTANCE_att', 'R_DISTANCE_landed', 'B_DISTANCE_att',
#        'B_DISTANCE_landed', 'R_CLINCH_att', 'R_CLINCH_landed', 'B_CLINCH_att',
#        'B_CLINCH_landed', 'R_GROUND_att', 'R_GROUND_landed', 'B_GROUND_att',
#        'B_GROUND_landed', 'title_bout', 'weight_class',
#        'total_time_fought(seconds)', 'no_of_rounds', 'R_CTRL_time(seconds)',
#        'B_CTRL_time(seconds)', 'win_by_Could Not Continue', 'win_by_DQ',
#        'win_by_Decision - Majority', 'win_by_Decision - Split',
#        'win_by_Decision - Unanimous', 'win_by_KO/TKO', 'win_by_Other',
#        'win_by_Overturned', 'win_by_Submission',
#        'win_by_TKO - Doctor's Stoppage'],
#       dtype='object')

# %%
Numerical_columns = ['hero_KD', 'opp_KD', 'hero_SIG_STR_pct',
       'opp_SIG_STR_pct', 'hero_TD_pct', 'opp_TD_pct', 'hero_SUB_ATT', 'opp_SUB_ATT',
        'hero_REV', 'opp_REV', 'hero_SIG_STR._att', 'hero_SIG_STR._landed',
       'opp_SIG_STR._att', 'opp_SIG_STR._landed', 'hero_TOTAL_STR._att',
       'hero_TOTAL_STR._landed', 'opp_TOTAL_STR._att', 'opp_TOTAL_STR._landed',
       'hero_TD_att', 'hero_TD_landed', 'opp_TD_att', 'opp_TD_landed', 'hero_HEAD_att',
       'hero_HEAD_landed', 'opp_HEAD_att', 'opp_HEAD_landed', 'hero_BODY_att',
       'hero_BODY_landed', 'opp_BODY_att', 'opp_BODY_landed', 'hero_LEG_att',
       'hero_LEG_landed', 'opp_LEG_att', 'opp_LEG_landed', 'hero_DISTANCE_att',
       'hero_DISTANCE_landed', 'opp_DISTANCE_att', 'opp_DISTANCE_landed',
       'hero_CLINCH_att', 'hero_CLINCH_landed', 'opp_CLINCH_att', 'opp_CLINCH_landed',
       'hero_GROUND_att', 'hero_GROUND_landed', 'opp_GROUND_att', 'opp_GROUND_landed', 
        'hero_CTRL_time(seconds)', 'opp_CTRL_time(seconds)',
       'total_time_fought(seconds)']

Categorical_columns = ['win_by', 'last_round',
        'Winner', 'title_bout']

# %%
import re

def lreplace(pattern, sub, string):
    """
    Replaces 'pattern' in 'string' with 'sub' if 'pattern' starts 'string'.
    """
    return re.sub('^%s' % pattern, sub, string)

# %%
red = df.groupby('R_fighter')
blue = df.groupby('B_fighter')

# %%
def get_fighter_red(fighter_name):
    try:
        fighter_red = red.get_group(fighter_name)
    except:
        return None
    rename_columns = {}
    for column in fighter_red.columns:
        if re.search('^R_', column) is not None:
            rename_columns[column] = lreplace('R_', 'hero_', column)
        elif re.search('^B_', column) is not None:
            rename_columns[column] = lreplace('B_', 'opp_', column)
    fighter_red = fighter_red.rename(rename_columns, axis='columns')
    return fighter_red

# %%
def get_fighter_blue(fighter_name):
    try:
        fighter_blue = blue.get_group(fighter_name)
    except:
        return None
    rename_columns = {}
    for column in fighter_blue.columns:
        if re.search('^B_', column) is not None:
            rename_columns[column] = lreplace('B_', 'hero_', column)
        elif re.search('^R_', column) is not None:
            rename_columns[column] = lreplace('R_', 'opp_', column)
    fighter_blue = fighter_blue.rename(rename_columns, axis='columns')
    return fighter_blue

# %%
def get_result_stats(result_list):
    result_list.reverse() # To get it in ascending order
    current_win_streak = 0
    current_lose_streak = 0
    longest_win_streak = 0
    wins = 0
    losses = 0
    draw = 0
    for result in result_list:
        if result == 'hero':
            wins += 1
            current_win_streak += 1
            current_lose_streak = 0
            if longest_win_streak < current_win_streak:
                longest_win_streak += 1
        elif result == 'opp':
            losses += 1
            current_win_streak = 0
            current_lose_streak += 1
        elif result == 'draw':
            draw += 1
            current_lose_streak = 0
            current_win_streak = 0
            
    return current_win_streak, current_lose_streak, longest_win_streak, wins, losses, draw

# %%
win_by_columns = ['win_by_Decision - Majority', 'win_by_Decision - Split',
       'win_by_Decision - Unanimous', 'win_by_KO/TKO','win_by_Submission',
       'win_by_TKO - Doctor\'s Stoppage']

# %%
temp_blue_frame = pd.DataFrame()
temp_red_frame = pd.DataFrame()
result_stats = ['current_win_streak', 'current_lose_streak', 'longest_win_streak', 'wins', 'losses', 'draw']

for fighter_name in fighters:
    fighter_red = get_fighter_red(fighter_name)
    fighter_blue = get_fighter_blue(fighter_name)
    fighter_index = None
    
    if fighter_red is None:
        fighter = fighter_blue
        fighter_index = 'blue'
    elif fighter_blue is None:
        fighter = fighter_red
        fighter_index = 'red'
    else:
        fighter = pd.concat([fighter_red, fighter_blue]).sort_index()
    
    fighter['Winner'] = fighter['Winner'].apply(lambda X: 'hero' if X == fighter_name else 'opp')

    for i, index in enumerate(fighter.index):
        fighter_slice = fighter[(i+1):].sort_index(ascending=False)
        s = fighter_slice[Numerical_columns].ewm(span=3, adjust=False).mean().tail(1)
        if len(s) != 0:
            pass
        else:
            s.loc[len(s)] = [np.NaN for _ in s.columns]
        s['total_rounds_fought'] = fighter_slice['last_round'].sum()
        s['total_title_bouts'] = fighter_slice[fighter_slice['title_bout']==True]['title_bout'].count()
        s['hero_fighter'] = fighter_name
        results = get_result_stats(list(fighter_slice['Winner']))
        for result_stat, result in zip(result_stats, results):
            s[result_stat] = result
        win_by_results = fighter_slice[fighter_slice['Winner'] == 'hero'][win_by_columns].sum()
        for win_by_column,win_by_result in zip(win_by_columns, win_by_results):
            s[win_by_column] = win_by_result
        s.index = [index]


        if fighter_index is None:
            if index in fighter_blue.index:
                temp_blue_frame = pd.concat([temp_blue_frame, s])
            elif index in fighter_red.index:
                temp_red_frame = pd.concat([temp_red_frame, s])
        elif fighter_index == 'blue':
            temp_blue_frame = pd.concat([temp_blue_frame, s])
        elif fighter_index == 'red':
            temp_red_frame = pd.concat([temp_red_frame, s])

# %%
len(fighters)
# Out:
# 2295

# %%
fighter_details = fighter_details[fighter_details.index.isin(fighters)]
for col in fighter_details.columns:
    print(f"Number of NaN in {col} : {fighter_details[col].isnull().sum()}")
# Out:
# Number of NaN in Height : 13
# Number of NaN in Weight : 10
# Number of NaN in Reach : 641
# Number of NaN in Stance : 75
# Number of NaN in DOB : 141

# %%
fighter_details.columns
# Out:
# Index(['Height', 'Weight', 'Reach', 'Stance', 'DOB'], dtype='object')

# %%
def convert_to_cms(X):
    if X is np.NaN:
        return X
    elif len(X.split("'")) == 2:
        feet = float(X.split("'")[0])
        inches = int(X.split("'")[1].replace(' ', '').replace('"',''))
        return (feet * 30.48) + (inches * 2.54)
    else:
        return float(X.replace('"','')) * 2.54

# %%
fighter_details['Height_cms'] = fighter_details['Height'].apply(convert_to_cms)
fighter_details['Reach_cms'] = fighter_details['Reach'].apply(convert_to_cms)

# %%
fighter_details['Weight_lbs'] = fighter_details['Weight'].apply(lambda X: float(X.replace(' lbs.', '')) if X is not np.NaN else X)

# %%
fighter_details.drop(['Height', 'Weight', 'Reach'], axis=1, inplace=True)

# %%
fighter_details.reset_index(inplace=True)
temp_red_frame.reset_index(inplace=True)
temp_blue_frame.reset_index(inplace=True)

# %%
temp_blue_frame = temp_blue_frame.merge(fighter_details, left_on='hero_fighter', right_on='fighter_name', how='left')
temp_blue_frame.set_index('index', inplace=True)

# %%
temp_blue_frame[['hero_fighter', 'fighter_name', 'Height_cms', 'Weight_lbs', 'DOB']].head(20)
# Out:
#                    hero_fighter              fighter_name  Height_cms  \
# index
# 3858                 Tim Gorman                Tim Gorman      165.10
# 4162                 Tim Gorman                Tim Gorman      165.10
# 5291                  Tim Hague                 Tim Hague      193.04
# 5478                  Tim Hague                 Tim Hague      193.04
# 5538                  Tim Hague                 Tim Hague      193.04
# 5645                  Tim Hague                 Tim Hague      193.04
# 155              Sergey Morozov            Sergey Morozov      167.64
# 364              Sergey Morozov            Sergey Morozov      167.64
# 633              Sergey Morozov            Sergey Morozov      167.64
# 899              Sergey Morozov            Sergey Morozov      167.64
# 4389                Igor Araujo               Igor Araujo      185.42
# 3704                Cat Zingano               Cat Zingano      167.64
# 4564                Cat Zingano               Cat Zingano      167.64
# 3279            Felipe Olivieri           Felipe Olivieri      175.26
# 548                 Martin Sano               Martin Sano      180.34
# 3476   Antonio Rodrigo Nogueira  Antonio Rodrigo Nogueira      190.50
# 5020   Antonio Rodrigo Nogueira  Antonio Rodrigo Nogueira      190.50
# 5527   Antonio Rodrigo Nogueira  Antonio Rodrigo Nogueira      190.50
# 5779   Antonio Rodrigo Nogueira  Antonio Rodrigo Nogueira      190.50
# 6574             Alex Stiebling            Alex Stiebling      187.96
#
#        Weight_lbs           DOB
# index
# 3858        135.0  Apr 29, 1983
# 4162        135.0  Apr 29, 1983
# 5291        260.0  May 09, 1983
# 5478        260.0  May 09, 1983
# 5538        260.0  May 09, 1983
# 5645        260.0  May 09, 1983
# 155         135.0  Jun 14, 1989
# 364         135.0  Jun 14, 1989
# 633         135.0  Jun 14, 1989
# 899         135.0  Jun 14, 1989
# 4389        170.0  Dec 06, 1980
# 3704        145.0  Jul 01, 1982
# 4564        145.0  Jul 01, 1982
# 3279        155.0  Apr 12, 1985
# 548         170.0  May 30, 1991
# 3476        240.0  Jun 02, 1976
# 5020        240.0  Jun 02, 1976
# 5527        240.0  Jun 02, 1976
# 5779        240.0  Jun 02, 1976
# 6574        205.0           NaN

# %%
temp_red_frame = temp_red_frame.merge(fighter_details, left_on='hero_fighter', right_on='fighter_name', how='left')
temp_red_frame.set_index('index', inplace=True)

# %%
temp_blue_frame.drop('fighter_name', axis=1, inplace=True)
temp_red_frame.drop('fighter_name', axis=1, inplace=True)

# %%
blue_frame = temp_blue_frame.add_prefix('B_')
red_frame = temp_red_frame.add_prefix('R_')

# %%
frame = blue_frame.join(red_frame, how='outer')

# %%
rename_cols = {}
for col in frame.columns:
    if 'hero' in col:
        rename_cols[col] = col.replace('_hero_', '_avg_').replace('.', '')
    if 'opp' in col:
        rename_cols[col] = col.replace('_opp_', '_avg_opp_').replace('.', '')
    if 'win_by' in col:
        rename_cols[col] = col.replace(' ', '').replace('-', '_').replace('\'s', '_')

# %%
frame.rename(rename_cols, axis='columns', inplace=True)

# %%
frame.drop(['R_avg_fighter','B_avg_fighter'], axis=1, inplace=True)

# %%
df2.columns

# %%
df2 = df2.join(frame, how='outer')

# %%
df2['R_DOB'] = pd.to_datetime(df2['R_DOB'])
df2['B_DOB'] = pd.to_datetime(df2['B_DOB'])
df2['date'] = pd.to_datetime(df2['date'])

# %%
def get_age(row):
    B_age = (row['date'] - row['B_DOB']).days
    R_age = (row['date'] - row['R_DOB']).days
    if np.isnan(B_age)!=True:
        B_age = math.floor(B_age/365.25)
    if np.isnan(R_age)!=True:
        R_age = math.floor(R_age/365.25)
    return pd.Series([B_age, R_age], index=['B_age', 'R_age'])

# %%
df2[['B_age', 'R_age']]= df2[['date', 'R_DOB', 'B_DOB']].apply(get_age, axis=1)
df2.drop(['R_DOB', 'B_DOB'], axis=1, inplace=True)
df2.to_csv('../data/data.csv', index=False)

# %%
df2.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'Referee', 'date', 'location', 'Winner',
#        'title_bout', 'weight_class', 'no_of_rounds', 'B_avg_KD',
#        ...
#        'R_win_by_Decision_Unanimous', 'R_win_by_KO/TKO', 'R_win_by_Submission',
#        'R_win_by_TKO_Doctor_Stoppage', 'R_Stance', 'R_Height_cms',
#        'R_Reach_cms', 'R_Weight_lbs', 'B_age', 'R_age'],
#       dtype='object', length=145)
